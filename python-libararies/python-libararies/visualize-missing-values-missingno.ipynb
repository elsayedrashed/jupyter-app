# %%
import missingno
print("Missingno Version : {}".format(missingno.__version__))
# Out:
# Missingno Version : 0.5.1

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# Load datasets
starbucks_locations = pd.read_csv("../data/starbucks_store_locations.csv")
starbucks_locations.head()
# Out:
#        Brand  Store Number        Store Name Ownership Type  \
# 0  Starbucks  47370-257954     Meritxell, 96       Licensed
# 1  Starbucks  22331-212325  Ajman Drive Thru       Licensed
# 2  Starbucks  47089-256771         Dana Mall       Licensed
# 3  Starbucks  22126-218024        Twofour 54       Licensed
# 4  Starbucks  17127-178586      Al Ain Tower       Licensed
#
#                     Street Address              City State/Province Country  \
# 0                Av. Meritxell, 96  Andorra la Vella              7      AD
# 1             1 Street 69, Al Jarf             Ajman             AJ      AE
# 2     Sheikh Khalifa Bin Zayed St.             Ajman             AJ      AE
# 3                  Al Salam Street         Abu Dhabi             AZ      AE
# 4  Khaldiya Area, Abu Dhabi Island         Abu Dhabi             AZ      AE
#
#   Postcode Phone Number                 Timezone  Longitude  Latitude
# 0    AD500    376818720  GMT+1:00 Europe/Andorra       1.53     42.51
# 1      NaN          NaN     GMT+04:00 Asia/Dubai      55.47     25.42
# 2      NaN          NaN     GMT+04:00 Asia/Dubai      55.47     25.39
# 3      NaN          NaN     GMT+04:00 Asia/Dubai      54.38     24.48
# 4      NaN          NaN     GMT+04:00 Asia/Dubai      54.54     24.51

# %%
london_housing = pd.read_csv("../data/housing_in_london_yearly_variables.csv")
london_housing.head()
# Out:
#         code                  area        date  median_salary  \
# 0  E09000001        city of london  1999-12-01        33020.0
# 1  E09000002  barking and dagenham  1999-12-01        21480.0
# 2  E09000003                barnet  1999-12-01        19568.0
# 3  E09000004                bexley  1999-12-01        18621.0
# 4  E09000005                 brent  1999-12-01        18532.0
#
#    life_satisfaction mean_salary recycling_pct  population_size  \
# 0                NaN       48922             0           6581.0
# 1                NaN       23620             3         162444.0
# 2                NaN       23128             8         313469.0
# 3                NaN       21386            18         217458.0
# 4                NaN       20911             6         260317.0
#
#    number_of_jobs  area_size  no_of_houses  borough_flag
# 0             NaN        NaN           NaN             1
# 1             NaN        NaN           NaN             1
# 2             NaN        NaN           NaN             1
# 3             NaN        NaN           NaN             1
# 4             NaN        NaN           NaN             1

# %%
# Missing Data Bar Chart
missingno.bar(london_housing, figsize=(10,5), fontsize=12);

# %%
# Missing Data Bar Chart (Sorted)
missingno.bar(london_housing, color="dodgerblue", sort="ascending", figsize=(10,5), fontsize=12);

# %%
# Missing Data Bar Chart (Normal and Logarithmic Y-Axis)
fig = plt.figure(figsize=(15,7))

ax1 = fig.add_subplot(1,2,1)
missingno.bar(starbucks_locations, color="tomato", fontsize=12, ax=ax1);

ax2 = fig.add_subplot(1,2,2)
missingno.bar(starbucks_locations, log=True, color="tab:green", fontsize=12, ax=ax2);

plt.tight_layout()
# Out:
# /Users/dmmil/.pyenv/versions/env3.10.8/lib/python3.10/site-packages/missingno/missingno.py:271: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_yticklabels([int(n * len(df)) for n in ax1.get_yticks()], fontsize=fontsize)

# %%
# Dataset Missing Data Matrix Chart
missingno.matrix(starbucks_locations,figsize=(10,5), fontsize=12, color=(1, 0.38, 0.27));

# %%
# Missing Data Matrix Chart (Without Sparkline)
missingno.matrix(london_housing, sparkline=False, figsize=(10,5), fontsize=12, color=(0.27, 0.52, 1.0));

# %%
# Missing Data Heatmap
# The nullity correlation ranges from -1 to 1.
# -1 - Exact Negative correlation represents that if the value of one variable is present then the value of other variables is definitely absent.
#  0 - No correlation represents that variables' values present or absent do not have any effect on one another.
#  1 - Exact Positive correlation represents that if the value of one variable is present then the value of the other is definitely present.

missingno.heatmap(london_housing, cmap="RdYlGn", figsize=(10,5), fontsize=12);

# %%
# Missing Data Dendrogram
missingno.dendrogram(london_housing, figsize=(10,5), fontsize=12);

# %%
# Dataset Missing Data Dendrogram with different methods
fig = plt.figure(figsize=(15,7))

ax1 = fig.add_subplot(1,2,1)
missingno.dendrogram(london_housing, orientation="bottom", method="centroid", fontsize=12, ax=ax1);

ax2 = fig.add_subplot(1,2,2)
missingno.dendrogram(london_housing, orientation="top", method="ward", fontsize=12, ax=ax2);

plt.tight_layout()

# %%
import os
# os.environ["MODIN_ENGINE"] = "ray"  # Modin will use Ray
os.environ["MODIN_ENGINE"] = "dask"  # Modin will use Dask
# os.environ["MODIN_ENGINE"] = "unidist" # Modin will use Unidist
# os.environ["UNIDIST_BACKEND"] = "mpi" # Unidist will use MPI backend
import modin.pandas as pd
# import ray

# ray.init(ignore_reinit_error=True)
df = pd.read_csv("../data/gsod/*.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-fdefb50c4e0c> in <module>
#       8
#       9 # ray.init(ignore_reinit_error=True)
# ---> 10 df = pd.read_csv("../data/gsod/*.csv")
#
# ~/.pyenv/versions/env3.10.8/lib/python3.10/site-packages/modin/logging/logger_decorator.py in run_and_log(*args, **kwargs)
#     126             """
#     127             if LogMode.get() == "disable":
# --> 128                 return obj(*args, **kwargs)
#     129
#     130             logger = get_logger()
#
# ~/.pyenv/versions/env3.10.8/lib/python3.10/site-packages/modin/pandas/io.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     216     f_locals.pop("mangle_dupe_cols", None)
#     217     kwargs = {k: v for k, v in f_locals.items() if k in _pd_read_csv_signature}
# --> 218     return _read(**kwargs)
#     219
#     220
#
# ~/.pyenv/versions/env3.10.8/lib/python3.10/site-packages/modin/pandas/io.py in _read(**kwargs)
#      87
#      88     squeeze = kwargs.pop("squeeze", False)
# ---> 89     pd_obj = FactoryDispatcher.read_csv(**kwargs)
#      90     # This happens when `read_csv` returns a TextFileReader object for iterating through
#      91     if isinstance(pd_obj, TextFileReader):
#
# ~/.pyenv/versions/env3.10.8/lib/python3.10/site-packages/modin/core/execution/dispatching/factories/dispatcher.py in read_csv(cls, **kwargs)
#     183     @_inherit_docstrings(factories.BaseFactory._read_csv)
#     184     def read_csv(cls, **kwargs):
# --> 185         return cls.get_factory()._read_csv(**kwargs)
#     186
#     187     @classmethod
#
# ~/.pyenv/versions/env3.10.8/lib/python3.10/site-packages/modin/core/execution/dispatching/factories/factories.py in _read_csv(cls, **kwargs)
#     215     )
#     216     def _read_csv(cls, **kwargs):
# --> 217         return cls.io_cls.read_csv(**kwargs)
#     218
#     219     @classmethod
#
# ~/.pyenv/versions/env3.10.8/lib/python3.10/site-packages/modin/logging/logger_decorator.py in run_and_log(*args, **kwargs)
#     126             """
#     127             if LogMode.get() == "disable":
# --> 128                 return obj(*args, **kwargs)
#     129
#     130             logger = get_logger()
#
# ~/.pyenv/versions/env3.10.8/lib/python3.10/site-packages/modin/core/io/file_dispatcher.py in read(cls, *args, **kwargs)
#     152         postprocessing work on the resulting query_compiler object.
#     153         """
# --> 154         query_compiler = cls._read(*args, **kwargs)
#     155         # TODO (devin-petersohn): Make this section more general for non-pandas kernel
#     156         # implementations.
#
# ~/.pyenv/versions/env3.10.8/lib/python3.10/site-packages/modin/logging/logger_decorator.py in run_and_log(*args, **kwargs)
#     126             """
#     127             if LogMode.get() == "disable":
# --> 128                 return obj(*args, **kwargs)
#     129
#     130             logger = get_logger()
#
# ~/.pyenv/versions/env3.10.8/lib/python3.10/site-packages/modin/core/io/text/text_file_dispatcher.py in _read(cls, filepath_or_buffer, **kwargs)
#    1016         )
#    1017         if not use_modin_impl:
# -> 1018             return cls.single_worker_read(
#    1019                 filepath_or_buffer,
#    1020                 callback=cls.read_callback,
#
# ~/.pyenv/versions/env3.10.8/lib/python3.10/site-packages/modin/logging/logger_decorator.py in run_and_log(*args, **kwargs)
#     126             """
#     127             if LogMode.get() == "disable":
# --> 128                 return obj(*args, **kwargs)
#     129
#     130             logger = get_logger()
#
# ~/.pyenv/versions/env3.10.8/lib/python3.10/site-packages/modin/core/storage_formats/pandas/parsers.py in single_worker_read(cls, fname, reason, **kwargs)
#     279         ErrorMessage.default_to_pandas(reason=reason)
#     280         # Use default args for everything
# --> 281         pandas_frame = cls.parse(fname, **kwargs)
#     282         if isinstance(pandas_frame, pandas.io.parsers.TextFileReader):
#     283             pd_read = pandas_frame.read
#
# ~/.pyenv/versions/env3.10.8/lib/python3.10/site-packages/modin/logging/logger_decorator.py in run_and_log(*args, **kwargs)
#     126             """
#     127             if LogMode.get() == "disable":
# --> 128                 return obj(*args, **kwargs)
#     129
#     130             logger = get_logger()
#
# ~/.pyenv/versions/env3.10.8/lib/python3.10/site-packages/modin/core/storage_formats/pandas/parsers.py in parse(fname, **kwargs)
#     303     @doc(_doc_parse_func, parameters=_doc_parse_parameters_common)
#     304     def parse(fname, **kwargs):
# --> 305         return PandasParser.generic_parse(fname, **kwargs)
#     306
#     307
#
# ~/.pyenv/versions/env3.10.8/lib/python3.10/site-packages/modin/logging/logger_decorator.py in run_and_log(*args, **kwargs)
#     126             """
#     127             if LogMode.get() == "disable":
# --> 128                 return obj(*args, **kwargs)
#     129
#     130             logger = get_logger()
#
# ~/.pyenv/versions/env3.10.8/lib/python3.10/site-packages/modin/core/storage_formats/pandas/parsers.py in generic_parse(fname, **kwargs)
#     158         if start is None or end is None:
#     159             # This only happens when we are reading with only one worker (Default)
# --> 160             return callback(fname, **kwargs)
#     161
#     162         # pop "compression" from kwargs because bio is uncompressed
#
# ~/.pyenv/versions/env3.10.8/lib/python3.10/site-packages/modin/logging/logger_decorator.py in run_and_log(*args, **kwargs)
#     126             """
#     127             if LogMode.get() == "disable":
# --> 128                 return obj(*args, **kwargs)
#     129
#     130             logger = get_logger()
#
# ~/.pyenv/versions/env3.10.8/lib/python3.10/site-packages/modin/core/io/text/csv_dispatcher.py in read_callback(*args, **kwargs)
#      38             Function call result.
#      39         """
# ---> 40         return pandas.read_csv(*args, **kwargs)
#
# ~/.pyenv/versions/env3.10.8/lib/python3.10/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# ~/.pyenv/versions/env3.10.8/lib/python3.10/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ~/.pyenv/versions/env3.10.8/lib/python3.10/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     948     kwds.update(kwds_defaults)
#     949
# --> 950     return _read(filepath_or_buffer, kwds)
#     951
#     952
#
# ~/.pyenv/versions/env3.10.8/lib/python3.10/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     603
#     604     # Create the parser.
# --> 605     parser = TextFileReader(filepath_or_buffer, **kwds)
#     606
#     607     if chunksize or iterator:
#
# ~/.pyenv/versions/env3.10.8/lib/python3.10/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1440
#    1441         self.handles: IOHandles | None = None
# -> 1442         self._engine = self._make_engine(f, self.engine)
#    1443
#    1444     def close(self) -> None:
#
# ~/.pyenv/versions/env3.10.8/lib/python3.10/site-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1733                 if "b" not in mode:
#    1734                     mode += "b"
# -> 1735             self.handles = get_handle(
#    1736                 f,
#    1737                 mode,
#
# ~/.pyenv/versions/env3.10.8/lib/python3.10/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854         if ioargs.encoding and "b" not in ioargs.mode:
#     855             # Encoding
# --> 856             handle = open(
#     857                 handle,
#     858                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/gsod/*.csv'

# %%
df.head
# Out:
# <bound method BasePandasDataset.head of         STATION        DATE   LATITUDE  LONGITUDE  ELEVATION  \
# 0    1001099999  2020-01-01  70.933333  -8.666667        9.0
# 1    1001099999  2020-01-02  70.933333  -8.666667        9.0
# 2    1001099999  2020-01-03  70.933333  -8.666667        9.0
# 3    1001099999  2020-01-04  70.933333  -8.666667        9.0
# 4    1001099999  2020-01-05  70.933333  -8.666667        9.0
# ..          ...         ...        ...        ...        ...
# 360  1001099999  2020-12-27  70.933333  -8.666667        9.0
# 361  1001099999  2020-12-28  70.933333  -8.666667        9.0
# 362  1001099999  2020-12-29  70.933333  -8.666667        9.0
# 363  1001099999  2020-12-30  70.933333  -8.666667        9.0
# 364  1001099999  2020-12-31  70.933333  -8.666667        9.0
#
#                        NAME  TEMP  TEMP_ATTRIBUTES  DEWP  DEWP_ATTRIBUTES  \
# 0    JAN MAYEN NOR NAVY, NO  31.5               24  29.3               24
# 1    JAN MAYEN NOR NAVY, NO  26.0               24  23.4               24
# 2    JAN MAYEN NOR NAVY, NO  25.1               21  18.9               21
# 3    JAN MAYEN NOR NAVY, NO  24.1               23  16.1               23
# 4    JAN MAYEN NOR NAVY, NO  34.4               24  32.5               24
# ..                      ...   ...              ...   ...              ...
# 360  JAN MAYEN NOR NAVY, NO  33.9               24  27.5               24
# 361  JAN MAYEN NOR NAVY, NO  30.2               24  23.3               24
# 362  JAN MAYEN NOR NAVY, NO  30.5               24  28.7               24
# 363  JAN MAYEN NOR NAVY, NO  31.1               24  29.4               24
# 364  JAN MAYEN NOR NAVY, NO  26.8               24  24.4               24
#
#      ...  MXSPD  GUST   MAX  MAX_ATTRIBUTES   MIN MIN_ATTRIBUTES  PRCP  \
# 0    ...   15.9  24.1  35.8                  23.5              *  0.37
# 1    ...   37.3  49.1  34.2               *  19.0                 0.54
# 2    ...   50.5  65.9  33.6               *  19.6              *  0.31
# 3    ...   25.6  31.3  31.3               *  19.2                 0.06
# 4    ...   25.6  34.0  37.4                  26.4                 0.02
# ..   ...    ...   ...   ...             ...   ...            ...   ...
# 360  ...   34.2  50.1  39.6                  29.1                 0.02
# 361  ...   38.9  49.9  31.3                  29.5                 0.00
# 362  ...   36.1  49.7  31.3                  29.3                 0.00
# 363  ...   30.3  40.0  32.4                  29.3                 0.59
# 364  ...   32.8  42.0  30.2                  24.6                 0.29
#
#     PRCP_ATTRIBUTES   SNDP  FRSHTT
# 0                 G  999.9   10000
# 1                 E  999.9  101000
# 2                 E  999.9   10000
# 3                 G  999.9    1000
# 4                 G  999.9   10000
# ..              ...    ...     ...
# 360               G  999.9   11000
# 361               G  999.9       0
# 362               G  999.9    1000
# 363               G  999.9    1000
# 364               G  999.9    1000
#
# [365 rows x 28 columns]>

# %%
import dask.dataframe as dd
df = dd.read_csv("../data/gsod1980/*.csv")
df.compute().size
# Out:
# 63470484

# %%
df.compute().describe()
# Out:
#             STATION    LATITUDE   LONGITUDE   ELEVATION        TEMP  \
# count  6.480000e+02  646.000000  646.000000  646.000000  648.000000
# mean   1.000781e+09   66.086993   -2.573614   26.294985   40.244444
# std    8.866134e+06    5.527689    6.949677   19.726492   12.178332
# min    8.416000e+08   59.791925   -8.666667    9.000000    8.900000
# 25%    1.001100e+09   59.791925   -8.666667    9.000000   32.500000
# 50%    1.001100e+09   70.933333   -8.666667    9.000000   39.500000
# 75%    1.001500e+09   70.933333    5.340850   48.760000   45.925000
# max    1.001500e+09   70.933333    5.340850   48.760000   83.100000
#
#        TEMP_ATTRIBUTES        DEWP  DEWP_ATTRIBUTES          SLP  \
# count       648.000000  648.000000       648.000000   648.000000
# mean         17.674383   35.081636        17.669753  4905.674228
# std           7.187519   11.851039         7.189565  4461.027458
# min           4.000000    1.500000         4.000000   948.100000
# 25%          10.000000   28.200000        10.000000  1005.500000
# 50%          23.000000   35.600000        23.000000  1019.800000
# 75%          24.000000   42.500000        24.000000  9999.900000
# max          24.000000   73.200000        24.000000  9999.900000
#
#        SLP_ATTRIBUTES  ...  VISIB_ATTRIBUTES        WDSP  WDSP_ATTRIBUTES  \
# count      648.000000  ...        648.000000  648.000000       648.000000
# mean        13.367284  ...          7.550926   12.062654        17.640432
# std         11.772482  ...          2.922047    6.663077         7.179657
# min          0.000000  ...          0.000000    1.900000         4.000000
# 25%          0.000000  ...          6.000000    6.900000        10.000000
# 50%         23.000000  ...          6.000000   10.800000        23.000000
# 75%         24.000000  ...          8.000000   16.225000        24.000000
# max         24.000000  ...         18.000000   37.900000        24.000000
#
#             MXSPD        GUST          MAX          MIN        PRCP  \
# count  648.000000  648.000000   648.000000   648.000000  648.000000
# mean    19.082716  317.892130   135.713580   144.338889   26.282948
# std      9.090846  441.350462   954.421554  1030.783094   43.990305
# min      4.100000   10.100000    11.700000     6.600000    0.000000
# 25%     12.000000   27.600000    35.800000    28.750000    0.000000
# 50%     17.100000   39.000000    42.800000    36.900000    0.030000
# 75%     25.800000  999.900000    49.650000    43.225000   99.990000
# max     50.500000  999.900000  9999.900000  9999.900000   99.990000
#
#              SNDP         FRSHTT
# count  648.000000     648.000000
# mean   978.308951   24051.404321
# std    145.408484   39491.811172
# min      0.400000       0.000000
# 25%    999.900000       0.000000
# 50%    999.900000   10000.000000
# 75%    999.900000   11000.000000
# max    999.900000  111000.000000
#
# [8 rows x 23 columns]
